# %%
# Run this in a notebook
import os

model_path = r'C:\Users\srika\gw_wd\models\best_model.keras'

if os.path.exists(model_path):
    size_mb = os.path.getsize(model_path) / (1024 * 1024)
    print(f"Model size: {size_mb:.1f} MB")
    
    if size_mb > 100:
        print("⚠️ Too large for GitHub! We'll use alternative approach.")
    else:
        print("✅ Small enough for GitHub!")
else:
    print("❌ Model file not found")
# Out:
# Model size: 309.1 MB
# ⚠️ Too large for GitHub! We'll use alternative approach.
